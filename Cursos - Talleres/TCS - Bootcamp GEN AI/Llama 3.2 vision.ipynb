# %%
import ollama

response = ollama.chat(
    model='llama3.2-vision',
    messages=[{
        'role': 'user',
        'content': 'What is in this image?',
        'images': ['historia de usuario.png']
    }]
)

print(response)
# Out:
# model='llama3.2-vision' created_at='2025-02-06T19:41:37.9249124Z' done=True done_reason='stop' total_duration=276678721600 load_duration=20555373200 prompt_eval_count=18 prompt_eval_duration=219974000000 eval_count=71 eval_duration=35846000000 message=Message(role='assistant', content='The image shows a slide that depicts the user story: "As a potential customer, I want to read book reviews so that I can decide which one I want to buy." The text is written in black on a white background with light blue and pink lines underlining it. There are two orange squares in the upper left-hand corner of the image.', images=None, tool_calls=None)

# %%
import ollama

response = ollama.chat(
    model='llama3.2-vision',
    messages=[{
        'role': 'user',
        'content': 'describe la foto al detalle',
        'images': ['foto.jpg']
    }]
)

print(response)
# Out:
# model='llama3.2-vision' created_at='2025-03-07T23:29:11.763117Z' done=True done_reason='stop' total_duration=351754649900 load_duration=15936464600 prompt_eval_count=17 prompt_eval_duration=213981000000 eval_count=354 eval_duration=121346000000 message=Message(role='assistant', content='Esta imagen es una fotografía de grupo tomada en un ambiente informal, donde se aprecian cuatro hombres sentados sobre un sofá azul oscuro. La imagen incluye el torso y parte del rostro de uno de ellos, ubicado a la derecha del encuadre, que parece ser quien está tomando la fotografía.\n\nEl hombre al fondo izquierdo, con un vistoso atuendo amarillo, sostiene un vaso de cerveza en su mano. El segundo hombre desde la izquierda también sostiene un vaso de cerveza en una mano, mientras que el tercero se sienta sobre el sofá como los demás.\n\nEn el centro del encuadre, sobre el sofá, hay un portátil abierto y apagado. En el fondo de la imagen, detrás de la izquierda, se puede ver una mesa con una bandeja
# ...

# %%
import ollama

response = ollama.chat(
    model='llama3.2-vision',
    messages=[{
        'role': 'user',
        'content': 'What is in this image?',
        'images': ['zoologico.jpg']
    }]
)

print(response)
# Out:
# model='llama3.2-vision' created_at='2024-12-29T23:04:50.8223838Z' done=True done_reason='stop' total_duration=667168223200 load_duration=186291900 prompt_eval_count=18 prompt_eval_duration=593512000000 eval_count=152 eval_duration=73082000000 message=Message(role='assistant', content="This image shows a young child feeding giraffes at the Taronga Zoo in Sydney, Australia. The zoo is located on the shores of Sydney Harbour and offers stunning views of the city skyline.\n\nThe child is standing behind a fence, holding out a piece of food to feed the giraffe. The giraffe's long neck allows it to reach up over the fence to grab the food from the child's hand. There are several other giraffes in the background, as well as some trees and rocks. In the distance, you can see the Sydney Opera House and Harbour Bridge.\n\nOverall, this image captures a fun and educational moment for both the child and the giraffe. It's a great way to learn about these amazing animals and their habitats.", imag
# ...

# %%
import ollama

response = ollama.chat(
    model='llama3.2-vision',
    messages=[{
        'role': 'user',
        'content': 'What is in this image?',
        'images': ['citamedica.jpg']
    }]
)

print(response)
# Out:
# model='llama3.2-vision' created_at='2024-12-31T14:02:40.6926102Z' done=True done_reason='stop' total_duration=793216655600 load_duration=106165514100 prompt_eval_count=18 prompt_eval_duration=590010000000 eval_count=219 eval_duration=96594000000 message=Message(role='assistant', content='**Image Analysis**\n\nThe image presents a medical chart, likely from the 1990s or early 2000s, featuring handwritten notes and illegible abbreviations. The document includes several sections:\n\n*   **Allergies**: A section for recording allergies.\n*   **History and Complaints**: Notes on patient history and complaints.\n*   **Examination**: Details of the physical examination.\n*   **Provisional/Final Diagnosis**: Initial or final diagnosis written in cursive.\n*   **Drug Orders**: Prescribed medications with illegible abbreviations.\n*   **Nutritional Screening**: A section for nutritional assessment, including a graph and calculations.\n\n**Conclusion**\n\nThe image appears to be a medical chart
# ...

# %%
import ollama

response = ollama.chat(
    model='llama3.2-vision',
    messages=[{
        'role': 'user',
        'content': 'Describeme esta imagen y dame sugerencias sobre lo que esta sucediendo',
        'images': ['foto shaggy.png']
    }]
)

print(response)
# Out:
# model='llama3.2-vision' created_at='2025-02-06T19:51:58.5146027Z' done=True done_reason='stop' total_duration=356859262000 load_duration=115786700 prompt_eval_count=28 prompt_eval_duration=252185000000 eval_count=253 eval_duration=104130000000 message=Message(role='assistant', content='La imagen muestra una captura de pantalla de un videoconferencia virtual, donde se ven tres personas conectadas desde diferentes ubicaciones.\n\nEn la parte superior izquierda se encuentra Jorge Heman Abad Londoño, quien está usando una cámara de webcam con un fondo nocturno en el que se aprecian montañas nevadas y ciudades iluminadas por la noche. En su reloj aparece un texto blanco que dice "Jorge Heman Abad Londoño".\n\nEn la parte superior derecha, se encuentra Jorge Abad Londono sin mostrar su rostro, solo el círculo de fondo con su iniciales JL.\n\nPor último, en la parte inferior del marco, se encuentra Jorge Ramírez. Se aprecia que lleva un reloj sobre su muñeca izquierda y que tiene tatuados s
# ...
